# %%
import pandas as pd
data = pd.read_csv("car.csv")
data.head()
# Out:
#       年    地區   平均每戶全年交通費用  交通費用占家庭支出之百分比    汽車數合計     小客車數  大客車、大小貨車數  \
# 0  2020  臺閩地區   95744.0000       9.303022  8125594  6984750    1140844
# 1  2020  臺灣地區   95744.0000       9.303022  8077924  6942715    1135209
# 2  2020  北部區域  108476.4286       9.508890  3296142  2928056     368086
# 3  2020   臺北市   99527.0000       7.093441   806356   728947      77409
# 4  2020   新北市   86264.0000       8.548455  1030660   912214     118446
#
#       汽車持有率總計      小客車持有率       機車數       機車持有率
# 0  344.565028  296.187649  14103763  598.068707
# 1  344.788967  296.334991  14026462  598.689632
# 2  306.709003  272.458267   5460940  508.145421
# 3  307.331987  277.828564    946851  360.879809
# 4  256.075730  226.646873   2211719  549.519296

# %%
print("資料(資料筆數,欄位數量): ",data.shape)
print("資料中所有欄位名稱: ",data.columns)
print("資料中是否有空值: ",data.empty)
# Out:
# 資料(資料筆數,欄位數量):  (29, 11)
# 資料中所有欄位名稱:  Index(['年', '地區', '平均每戶全年交通費用', '交通費用占家庭支出之百分比', '汽車數合計', '小客車數', '大客車、大小貨車數',
#        '汽車持有率總計', '小客車持有率', '機車數', '機車持有率'],
#       dtype='object')
# 資料中是否有空值:  False

# %%
loc1 = data.loc[15:28,["汽車數合計","汽車持有率總計","小客車持有率"]]
loc1
# Out:
#       汽車數合計     汽車持有率總計      小客車持有率
# 15   281052  413.865919  326.378187
# 16  2241796  353.756197  297.565543
# 17   912403  329.439100  281.546741
# 18   698041  371.711340  317.427632
# 19    96233  360.629198  311.975941
# 20   206002  410.938027  324.671801
# 21   295924  362.687074  288.476458
# 22    33193  314.388683  269.607263
# 23   207531  383.372080  306.766384
# 24   126157  387.806074  316.652296
# 25    81374  376.694858  291.879030
# 26    47670  310.402084  273.709914
# 27    44086  314.022979  278.030643
# 28     3584  271.844660  227.700243
