# %%
import json
import bs4
import os
import urllib.request as req

import requests
response = requests.get("https://technews.tw/")
#對網頁發出請求
soup = bs4.BeautifulSoup(response.text, "html.parser")
#prettify()>>將soup這個物件美化
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <!--[if IE 7]>
# <html class="ie ie7" lang="zh-TW">
# <![endif]-->
# <!--[if IE 8]>
# <html class="ie ie8" lang="zh-TW">
# <![endif]-->
# <!--[if !(IE 7) | !(IE 8)  ]><!-->
# <html lang="zh-TW">
#  <!--<![endif]-->
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    TechNews 科技新報 | 市場和業內人士關心的趨勢、內幕與新聞
#   </title>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <meta content="5DEC29CE8988D72A1C6791568D17E9F3" name="msvalidate.01">
#    <meta content="Fb8JUo8FsCKBCR6sNHNW83sKPV3W1YRAbpmeWVK0OqA" name="google-site-verification"/>
#    <meta content="10.0.0.238" name="tf"/>
#    <meta content="TechNews 科技新報 | 市場和業內人士關心的趨勢、內幕與新聞" name="Title"/>
#    <meta content="科技新報 （TechNews）成立於 2013 年下半年，是專注於資訊科技、能源、半導體、行動運算、網際網路、醫療、生物科技等涵蓋各種產業與新科技的網路媒體，希望能給予對資訊科技有需求的讀者一個廣泛且有觀點與特色的文章為目標。" name="Description"/>
#    <meta content="https://img.technews.tw/wp-content/themes/twentytwelve/library/images/logo.gif" name="thumbnail"/>
#    <!-- OG Meta -->
# ...

# %%
import json
import bs4
import os
import urllib.request as req
import requests

# %%
#儲存url
url_list = []
response = requests.get("https://technews.tw/")
#對網頁發出請求
soup = bs4.BeautifulSoup(response.text, "html.parser")
urls = soup.find_all("h1",class_="entry-title")
print(f"====================第1頁====================")
for url in urls:
#title_temp 暫時儲存資料的地方
    url_temp = url.select_one("a").get("href")
#幫他放入list
    url_list.append(url_temp)


for page in range(2, 20):  # 執行1~3頁
    response = requests.get("https://technews.tw/"+"page/"+str(page)+"/")
#對網頁發出請求
    soup = bs4.BeautifulSoup(response.text, "html.parser")

#先幫他見一個list
    
#尋找要的地址位置、以及幫他放入list
    urls = soup.find_all("h1",class_="entry-title")
    print(f"====================第{str(page)}頁====================")
    for url in urls:
    #title_temp 暫時儲存資料的地方
        url_temp = url.select_one("a").get("href")
    #幫他放入list
        url_list.append(url_temp)
print(url_list)

import pandas as pd 
df = pd.DataFrame(url_list)
print(df)
# Out:
# ====================第1頁====================
# ====================第2頁====================
# ====================第3頁====================
# ====================第4頁====================
# ====================第5頁====================
# ====================第6頁====================
# ====================第7頁====================
# ====================第8頁====================
# ====================第9頁====================
# ====================第10頁====================
# ====================第11頁====================
# ====================第12頁====================
# ====================第13頁====================
# ====================第14頁====================
# ====================第15頁====================
# ====================第16頁====================
# ====================第17頁====================
# ====================第18頁====================
# ====================第19頁====================
# ...

# %%
#print(ord(/))

# %%
title_list = []

response = requests.get("https://technews.tw/")
#對網頁發出請求
soup = bs4.BeautifulSoup(response.text, "html.parser")
#先幫他見一個list
    
#尋找要的地址位置、以及幫他放入list
titles = soup.find_all("h1", class_="entry-title")
for title in titles:
    #title_temp 暫時儲存資料的地方
    title_temp = title.a.text
    #######給我把那個可惡的/刪掉！！！！
    string = ''
    for char in title_temp:
        if 47 != ord(char):#用ASCII找 https://www.ascii-code.com/
            string += char 
    #幫他放入list
    title_list.append(string)
    
print(title_list)
print(f"====================第1頁====================")


for page in range(2, 20):  # 執行1~3頁
    response = requests.get("https://technews.tw/"+ "page/"+str(page)+"/")
#對網頁發出請求
    soup = bs4.BeautifulSoup(response.text, "html.parser")
#先幫他見一個list
    
#尋找要的地址位置、以及幫他放入list
    titles = soup.find_all("h1",class_="entry-title")
    for title in titles:
    #title_temp 暫時儲存資料的地方
        title_temp = title.a.text
        
        #######給我把那個可惡的/刪掉！！！！
        string = ''
        for char in title_temp:
            if 47 != ord(char):
                string += char 
    #幫他放入list
        title_list.append(string)
        
        
    print(title_list)
    print(f"====================第{str(page)}頁====================")

import pandas as pd 
df = pd.DataFrame(title_list)
print(df)
# Out:
# ['馬斯克傳 2018 年提收購 OpenAI 遭拒，反悔未兌現 10 億美元投資', '對 S-400 興趣越來越低，土耳其將推動自製防空飛彈系統', '處理 TikTok 國安疑慮，美眾院議長預期國會將通過法案', '幾何之美，數學家發現平鋪時永不重複圖案的單一形狀', '人工智慧市場需求持續發展，ASML 將成為當然受惠廠商', '目標 2030 全電動，漢堡王已經將三分之一車輛電動化', '普發現金又發現偽冒網址！財政部：已報警啟動防護', '蘇姿丰：人工智慧是未來 10 年最重要的事，釋放更多算力還需更多努力', '摩爾勾勒半導體升級標竿，專家：3 大方向助定律延續', 'K&S 盼下半年到年底前出現「U 型反轉」，繼續走長期策略', '敘利亞民兵三度攻擊美軍基地造成一死六傷，拜登下令 F-15E 轟炸報復', '力拚台積電，三星積極布局發展先進異質整合半導體封裝技術', '庫克訪中國直營店，卻被小米 13 搶盡風頭', '石油開採誘惑太大，氣候友善國挪威重金投資離岸油田', '台積電 2023 年半導體品牌價值緊咬英特爾，還獲得 AA+ 評價等級']
# ====================第1頁====================
# ...

# %%
title_list[7]
# Out:
# '蘇姿丰：人工智慧是未來 10 年最重要的事，釋放更多算力還需更多努力'

# %%
url_list[7]
# Out:
# 'https://technews.tw/2023/03/25/burgerking-onethird-fleet-electrified/'

# %%
headers = {
    "Referer": url_list[0],
}
article = requests.get(url_list[0],headers = headers)
#對網頁發出請求
soup = bs4.BeautifulSoup(article.text, "html.parser")
#prettify()>>將soup這個物件美化
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <!--[if IE 7]>
# <html class="ie ie7" lang="zh-TW">
# <![endif]-->
# <!--[if IE 8]>
# <html class="ie ie8" lang="zh-TW">
# <![endif]-->
# <!--[if !(IE 7) | !(IE 8)  ]><!-->
# <html lang="zh-TW">
#  <!--<![endif]-->
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Canva 免費平面設計工具也 AI！透過提示自動生成簡報 | TechNews 科技新報
#   </title>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <meta content="5DEC29CE8988D72A1C6791568D17E9F3" name="msvalidate.01">
#    <meta content="Fb8JUo8FsCKBCR6sNHNW83sKPV3W1YRAbpmeWVK0OqA" name="google-site-verification"/>
#    <meta content="10.0.0.26" name="tf"/>
#    <meta content="Canva 免費平面設計工具也 AI！透過提示自動生成簡報 | TechNews 科技新報" name="Title"/>
#    <meta content="Canva 懷抱「讓每個人都能設計出任何東西」的願景於 2013 年推出，至今每月用戶數超過 1.2 億，全球使用其平台輸出的設計作品已超過 150 億件。該工具除了免費版外，舉凡專業版及團體版皆可免費試用。該平台於週四（23 日）在所舉辦的 Canva Create 虛推活動中推出一系列包含 AI..." name="Description"/>
# ...

# %%
#先幫他見一個list
article_list = []
#尋找要的地址位置、以及幫他放入list
articles = soup.find("div",class_="indent")

for article in articles:
    #article_temp 暫時儲存資料的地方
    article_temp = article.string
    article_list.append(article_temp)
print(article_list)
    #幫他放入list

#alltitle = soup.find_all("h1",class_="entry-title") 
# 尋找所有在 div 標籤內 class="zIH PC4 XiG" 
#print(alltitle)
# Out:
# ['\n', None, None, None, None, '\n', '首先，該公司推出了可以搜尋各種設計元素並快速存取各種功能的 Assistant 助理工具。針對使用者現有的設計該搭配什麼圖片及樣式才好看，該工具能提供最佳推薦。', '\n', 'Canva 早在 12 月便推出以 AI 文案助理為訴求的 Magic Write AI 設計工具，但之前只能在 Canva Docs 中存取。如今不但能透過 Assistant 助理工具快速存取，並可在舉凡簡報、社交媒體圖片及傳單等所有 Canva 專案類型中使用。使用者可透過 Magic Write 編寫網站副本、簡報摘要，並列出在社交媒體上進行新品發布的策略想法。該公司並宣布，這個 AI 工具已支援 18 種語言。', '\n', '該平台並推出自動生成簡報的新方法，只要提示編輯器便能為每張投影片列出大綱和內容，進而方便快速地建立各種簡報。最值得一提的莫過 Brand Hub 品牌中心，它集結了一系列能幫助團隊彰顯自家品牌形象與價值的新工具與功能，例如 Magic Replace 工具，它可以讓使用者為所有設計快速更新像是商標等品牌資產。此外還包括能協助使用者創建品牌範本、資料夾和指南等工具。管理者還可直接在 Canva 中批準工作流程，以確保設計在發布之前能快速完成審核與批準。', '\n', '連圖片內容都可輕鬆替換，自動將設計中文字翻成 100 種其他語言', '\n', '除此之外，Canva 還推出許多非常方便又強大的新 AI 功能，透過 Magic Design 功能，使用者只要上傳圖片再選定風格，該功能會為使用者客製化個性化專屬範本。另外，Magic Edit 功能可以方便新增或替換圖片中的任何東西，使用者可以直接描述想在圖片中新增什麼物件。至於 Beat Sync 功能能自動為視訊片段配上使用者選擇的背景音樂，Translate 功能則可自動將設計中的文字翻成 100 種不同語言。', '\n', '有趣的是，Canva 還推出了許多應用戶要求的新功能，包括 Draw 功能，使用者隨手畫出歪七扭八的圖形，該功能會自動變成漂亮圓滑的圖形。其中 Layout 功能，使用者只要在某頁面上新增內容，該功能會立即提供設計上該如何佈局的建議。該平台並新增了 953 種新字體，這也成了另一個受歡迎的更新
# ...

# %%
filename = './allarticle/' + title_list[0] + '.txt'
filename
# Out:
# './allarticle/馬斯克傳 2018 年提收購 OpenAI 遭拒，反悔未兌現 10 億美元投資.txt'

# %%
newfile = open (filename, 'w')
s = ''.join(filter(lambda x: x if x is not None else '', article_list))
print(s)
newfile.write(s)
newfile.close()
# Out:
# 首先，該公司推出了可以搜尋各種設計元素並快速存取各種功能的 Assistant 助理工具。針對使用者現有的設計該搭配什麼圖片及樣式才好看，該工具能提供最佳推薦。
# Canva 早在 12 月便推出以 AI 文案助理為訴求的 Magic Write AI 設計工具，但之前只能在 Canva Docs 中存取。如今不但能透過 Assistant 助理工具快速存取，並可在舉凡簡報、社交媒體圖片及傳單等所有 Canva 專案類型中使用。使用者可透過 Magic Write 編寫網站副本、簡報摘要，並列出在社交媒體上進行新品發布的策略想法。該公司並宣布，這個 AI 工具已支援 18 種語言。
# 該平台並推出自動生成簡報的新方法，只要提示編輯器便能為每張投影片列出大綱和內容，進而方便快速地建立各種簡報。最值得一提的莫過 Brand Hub 品牌中心，它集結了一系列能幫助團隊彰顯自家品牌形象與價值的新工具與功能，例如 Magic Replace 工具，它可以讓使用者為所有設計快速更新像是商標等品牌資產。此外還包括能協助使用者創建品牌範本、資料夾和指南等工具。管理者還可直接在 Canva 中批準工作流程，以確保設計在發布之前能快速完成審核與批準。
# 連圖片內容都可輕鬆替換，自動將設計中文字翻成 100 種其他語言
# 除此之外，Canva 還推出許多非常方便又強大的新 AI 功能，透過 Magic Design 功能，使用者只要上傳圖片再選定風格，該功能會為使用者客製化個性化專屬範本。另外，Magic Edit 功能可以方便新增或替換圖片中的任何東西，使用者可以直接描述想在圖片中新增什麼物件。至於 Beat Sync 功能能自動為視訊片段配上使用者選擇的背景音樂，Translate 功能則可自動將設計中的文字翻成 100 種不同語言。
# 有趣的是，Canva 還推出了許多應用戶要求的新功能，包括 Draw 功能，使用者隨手畫出歪七扭八的圖形，該功能會自動變成漂亮圓滑的圖形。其中 Layout 功能，使用者只要在某頁面上新增內容，該功能會立即提供設計上該如何佈局的建議。該平台並新增了 953 種新字體，這也成了另一個受歡迎的更新之處。

# %%
a = 0
while a < 101:
    headers = {
        "Referer": url_list[a],
    }
    article = requests.get(url_list[a],headers = headers)
    #對網頁發出請求
    soup = bs4.BeautifulSoup(article.text, "html.parser")
    #prettify()>>將soup這個物件美化

    #先幫他見一個list
    article_list = []
    #尋找要的地址位置、以及幫他放入list
    articles = soup.find("div",class_="indent")

    for article in articles:
        #article_temp 暫時儲存資料的地方
        article_temp = article.string
        article_list.append(article_temp)
    print(article_list)
    #幫他放入list

    #alltitle = soup.find_all("h1",class_="entry-title") 
    # 尋找所有在 div 標籤內 class="zIH PC4 XiG" 
    #print(alltitle)

    filename = './230312newarticle/' + title_list[a] + '.txt'
    print(filename)
    newfile = open (filename, 'w', encoding='utf-8')
    s = ''.join(filter(lambda x: x if x is not None else '', article_list))
    print(s)
    newfile.write(s)
    newfile.close()
    a = a+1
    print(a,"完成")
# Out:
# ['\n', None, None, None, None, '\n', '首先，該公司推出了可以搜尋各種設計元素並快速存取各種功能的 Assistant 助理工具。針對使用者現有的設計該搭配什麼圖片及樣式才好看，該工具能提供最佳推薦。', '\n', 'Canva 早在 12 月便推出以 AI 文案助理為訴求的 Magic Write AI 設計工具，但之前只能在 Canva Docs 中存取。如今不但能透過 Assistant 助理工具快速存取，並可在舉凡簡報、社交媒體圖片及傳單等所有 Canva 專案類型中使用。使用者可透過 Magic Write 編寫網站副本、簡報摘要，並列出在社交媒體上進行新品發布的策略想法。該公司並宣布，這個 AI 工具已支援 18 種語言。', '\n', '該平台並推出自動生成簡報的新方法，只要提示編輯器便能為每張投影片列出大綱和內容，進而方便快速地建立各種簡報。最值得一提的莫過 Brand Hub 品牌中心，它集結了一系列能幫助團隊彰顯自家品牌形象與價值的新工具與功能，例如 Magic Replace 工具，它可以讓使用者為所有設計快速更新像是商標等品牌資產。此外還包括能協助使用者創建品牌範本、資料夾和指南等工具。管理者還可直接在 Canva 中批準工作流程，以確保設計在發布之前能快速完成審核與批準。', '\n', '連圖片內容都可輕鬆替換，自動將設計中文字翻成 100 種其他語言', '\n', '除此之外，Canva 還推出許多非常方便又強大的新 AI 功能，透過 Magic Design 功能，使用者只要上傳圖片再選定風格，該功能會為使用者客製化個性化專屬範本。另外，Magic Edit 功能可以方便新增或替換圖片中的任何東西，使用者可以直接描述想在圖片中新增什麼物件。至於 Beat Sync 功能能自動為視訊片段配上使用者選擇的背景音樂，Translate 功能則可自動將設計中的文字翻成 100 種不同語言。', '\n', '有趣的是，Canva 還推出了許多應用戶要求的新功能，包括 Draw 功能，使用者隨手畫出歪七扭八的圖形，該功能會自動變成漂亮圓滑的圖形。其中 Layout 功能，使用者只要在某頁面上新增內容，該功能會立即提供設計上該如何佈局的建議。該平台並新增了 953 種新字體，這也成了另一個受歡迎的更新
# ...

# %%
'./allarticle/台股底部還沒到不要貪婪！凱基投顧朱晏民：明年第三季落底.txt'
def mkdir(path):
    # 引入模組
    import os
 
    # 去除首位空格
    path=path.strip()
    # 去除尾部 \ 符號
    path=path.rstrip("\\")
 
    # 判斷路徑是否存在
    # 存在     True
    # 不存在   False
    isExists=os.path.exists(path)
 
    # 判斷結果
    if not isExists:
        # 如果不存在則建立目錄
        # 建立目錄操作函式
        os.makedirs(path) 
 
        print (path+'建立成功')
        return True
    else:
        # 如果目錄存在則不建立，並提示目錄已存在
        print (path+' 目錄已存在')
        return False
 
# 定義要建立的目錄
mkpath="230312newarticle\\"
# 呼叫函式
mkdir(mkpath)
# Out:
# 230312newarticle 目錄已存在
# False

# %%
#儲存title
title_list = []
for page in range(1, 6):  # 執行1~3頁
    response = requests.get("https://www.blocktempo.com/category/cryptocurrency-market/"+ str(page)+"/")
#對網頁發出請求
    soup = bs4.BeautifulSoup(response.text, "html.parser")
#先幫他見一個list
    
#尋找要的地址位置、以及幫他放入list
    titles = soup.find_all("h3", class_="jeg_post_title")
    for title in titles:
    #title_temp 暫時儲存資料的地方
        title_temp = title.a.text
        print(title_temp)
    #幫他放入list
        title_list.append(title_temp)
    print(title_list)
    print(f"====================第{str(page)}頁====================")

import pandas as pd 
df = pd.DataFrame(title_list)
print(df)
# Out:
# 警示》Arbitrum官方 Discord 遭駭客入侵！發布空投釣魚連結；官方 : 狀況已解除
# CryptoPunk #685 NFT 失誤燒毀！痛失 77 ETH 苦主現身說法…
# 一文看懂何謂「套利」| 加密貨幣無風險期權實例 & 操作教學
# Terra創辦人 Do Kwon 上銬畫面曝光！遭逮前試圖坐私人飛機前往杜拜
# 亞馬遜官方錯發email露餡！信函提及數位代幣、NFT、畫廊、轉售…
# 股壇教父｜華頓商學院教授 Siegel：當人們「對銀行恢復信心，比特幣就會跌落！」
# Do Kwon黑山被捕》控偽造文書、將進行引渡聽證會；SEC前官員：美國有Luna案管轄權！
# Open AI權力鬥爭》馬斯克傳2018年提收購遭拒、反悔未兌現10億鎂投資
# 快訊》幣安於晚間10點恢復「現貨交易、提存款」等功能，追蹤訂單停修
# 自殺或謀殺，美國政府是加密友好銀行倒閉元兇？
# ChatGPT 通過 Google 三級工程師面試，年薪破 500 萬台幣！
# FTX受害者必讀》10年交易所維權經驗的Tom告訴你：該自己請律師？要等多久？Steaker疑點？
# 富爸爸預言全中！瑞信被收購、黃金突破2000鎂…再砲轟聯準會「通膨大騙子」
# 警示》Arbitrum官方 Discord 遭駭客入侵！發布空投釣魚連結；官方 : 狀況已解除
# CryptoPunk #685 NFT 失誤燒毀！痛失 77 ETH 苦主現身說法…
# 一文看懂何謂「套利」| 加密貨幣無風險期權實例 & 操作教學
# ...
